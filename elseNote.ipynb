# %%
print("Your Task will only work on Weekdays")

# %%
# %python
var = dbutils.jobs.taskValues.get(
    taskKey='weekdayTask', 
    key='weekdayoutput', 
    debugValue='default_value'
)

# %%
print(var)
